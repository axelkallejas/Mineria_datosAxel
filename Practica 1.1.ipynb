# %%
conda install -c conda-forge/label/gcc7 missingno
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = 'materiales_recolectados.csv'
df = pd.read_csv(path, encoding='latin', error_bad_lines=False)
df.head()
# Out:
#   TIPO_DE_MATERIAL_VALORIZADO_RECOLECTADO  \
# 0                          Papel y carton
# 1                                     PET
# 2                                Aluminio
# 3                   Cobre, bronce y plomo
# 4                  Fierro, lamina y acero
#
#    CANTIDAD_(CANTIDAD_RECOLECTADA_EN_KILOGRAMOS_POR_DIA)  \
# 0                                             143187
# 1                                              70798
# 2                                               6129
# 3                                               5709
# 4                                              21868
#
#    PORCENTAJE_(PORCENTAJE)  Unnamed: 3  Unnamed: 4 Unnamed: 5
# 0                     32.0         NaN         NaN        NaN
# 1                     15.8         NaN         NaN        NaN
# 2                      1.4         NaN         NaN        NaN
# 3                      1.3         NaN         NaN        NaN
# 4                      4.9         NaN         NaN        NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 6 columns):
# TIPO_DE_MATERIAL_VALORIZADO_RECOLECTADO                  9 non-null object
# CANTIDAD_(CANTIDAD_RECOLECTADA_EN_KILOGRAMOS_POR_DIA)    9 non-null int64
# PORCENTAJE_(PORCENTAJE)                                  9 non-null float64
# Unnamed: 3                                               0 non-null float64
# Unnamed: 4                                               0 non-null float64
# Unnamed: 5                                               1 non-null object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 560.0+ bytes

# %%
df.shape
# Out:
# (9, 6)

# %%
df.shape[0]
# Out:
# 9

# %%
df.shape[1]
# Out:
# 6

# %%
df.columns.values.tolist()
# Out:
# ['TIPO_DE_MATERIAL_VALORIZADO_RECOLECTADO',
#  'CANTIDAD_(CANTIDAD_RECOLECTADA_EN_KILOGRAMOS_POR_DIA)',
#  'PORCENTAJE_(PORCENTAJE)',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5']

# %%
df.dtypes
# Out:
# TIPO_DE_MATERIAL_VALORIZADO_RECOLECTADO                   object
# CANTIDAD_(CANTIDAD_RECOLECTADA_EN_KILOGRAMOS_POR_DIA)      int64
# PORCENTAJE_(PORCENTAJE)                                  float64
# Unnamed: 3                                               float64
# Unnamed: 4                                               float64
# Unnamed: 5                                                object
# dtype: object

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
df.replace({' ': np.nan}, inplace=True)

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5']

# %%
df.describe()
# Out:
#        CANTIDAD_(CANTIDAD_RECOLECTADA_EN_KILOGRAMOS_POR_DIA)  \
# count                                           9.000000
# mean                                        49784.777778
# std                                         43802.190184
# min                                          5709.000000
# 25%                                         21868.000000
# 50%                                         41115.000000
# 75%                                         70798.000000
# max                                        143187.000000
#
#        PORCENTAJE_(PORCENTAJE)  Unnamed: 3  Unnamed: 4  Unnamed: 5
# count                 9.000000         0.0         0.0         0.0
# mean                 11.122222         NaN         NaN         NaN
# std                   9.776346         NaN         NaN         NaN
# min                   1.300000         NaN         NaN         NaN
# 25%                   4.900000         NaN         NaN         NaN
# 50%                   9.200000         NaN         NaN         NaN
# 75%                  15.800000         NaN         NaN         NaN
# max                  32.000000         NaN         NaN         NaN

# %%
df.loc[[0]]
# Out:
#   TIPO_DE_MATERIAL_VALORIZADO_RECOLECTADO  \
# 0                          Papel y carton
#
#    CANTIDAD_(CANTIDAD_RECOLECTADA_EN_KILOGRAMOS_POR_DIA)  \
# 0                                             143187
#
#    PORCENTAJE_(PORCENTAJE)  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0                     32.0         NaN         NaN         NaN
