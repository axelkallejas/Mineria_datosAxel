# %%
conda install -c conda-forge/label/gcc7 missingno
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = 'residuos_solidos_urbanos.csv'
df = pd.read_csv(path, encoding='latin', error_bad_lines=False)
df.head()
# Out:
#    AÃO GENERACION_TOTAL_(MILLONES_DE_TONELADAS)  \
# 0  1992                                 21967.51
# 1  1993                                 28089.54
# 2  1994                                 29472.43
# 3  1995                                 30509.61
# 4  1996                                 31959.42
#
#    GENERACION_PER_CAPITA_(KG/HABITANTE/DIA)
# 0                                      0.69
# 1                                      0.88
# 2                                      0.89
# 3                                      0.92
# 4                                      0.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 3 columns):
# AÃO                                        21 non-null int64
# GENERACION_TOTAL_(MILLONES_DE_TONELADAS)    21 non-null object
# GENERACION_PER_CAPITA_(KG/HABITANTE/DIA)    21 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 632.0+ bytes

# %%
df.shape
# Out:
# (21, 3)

# %%
df.shape[0]
# Out:
# 21

# %%
df.shape[1]
# Out:
# 3

# %%
df.columns.values.tolist()
# Out:
# ['AÃ\x91O',
#  'GENERACION_TOTAL_(MILLONES_DE_TONELADAS)',
#  'GENERACION_PER_CAPITA_(KG/HABITANTE/DIA)']

# %%
df.dtypes
# Out:
# AÃO                                          int64
# GENERACION_TOTAL_(MILLONES_DE_TONELADAS)     object
# GENERACION_PER_CAPITA_(KG/HABITANTE/DIA)    float64
# dtype: object

# %%
df.isnull().any().any()
# Out:
# False

# %%
msno.matrix(df)
# Out:
# C:\Users\Axel\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 145 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Axel\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 145 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
msno.matrix(df)

# %%
msno.bar(df)
# Out:
# C:\Users\Axel\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 145 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Axel\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 145 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
df.describe()
# Out:
#               AÃO  GENERACION_PER_CAPITA_(KG/HABITANTE/DIA)
# count    21.000000                                 21.000000
# mean   2002.000000                                  0.902381
# std       6.204837                                  0.069707
# min    1992.000000                                  0.690000
# 25%    1997.000000                                  0.870000
# 50%    2002.000000                                  0.900000
# 75%    2007.000000                                  0.960000
# max    2012.000000                                  0.990000

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          AÃO  GENERACION_TOTAL_(MILLONES_DE_TONELADAS)  \
# count      21                                        21
# size       21                                        21
# nunique    21                                        21
#
#          GENERACION_PER_CAPITA_(KG/HABITANTE/DIA)
# count                                          21
# size                                           21
# nunique                                        15

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#     AÃO GENERACION_TOTAL_(MILLONES_DE_TONELADAS)  \
# 15  2007                                36 865.00
#
#     GENERACION_PER_CAPITA_(KG/HABITANTE/DIA)
# 15                                      0.96
