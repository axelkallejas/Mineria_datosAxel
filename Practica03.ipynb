# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.decomposition import PCA, KernelPCA
from sklearn.datasets import make_circles

# %%
path = 'pobreza.csv'
df = pd.read_csv(path)
df.head()
# Out:
#               estado_1  \
# 0       aguascalientes
# 1      baja_california
# 2  baja_california_sur
# 3             campeche
# 4             coahuila
#
#    porcentaje_de_la_poblacion_ocupada_sin_acceso_a_la_seguridad_social_2008  \
# 0                                               51.7
# 1                                               52.0
# 2                                               51.1
# 3                                               59.2
# 4                                               37.4
#
#    porcentaje_de_la_poblacion_ocupada_sin_acceso_a_la_seguridad_social_2010  \
# 0                                               49.3
# 1                                               57.3
# 2                                               49.6
# 3                                               61.0
# 4                                               38.7
#
#    porcentaje_de_la_poblacion_ocupada_sin_acceso_a_la_seguridad_social_2012  \
# ...

# %%
all_variables = ['Estado','2008','2010','2012','2014','2016','2018','Miles 2008','Miles 2010','Miles 2012','<65 2012','<65 2014','<65 2016','<65 2018','Miles <65 2008','miles<65 2010','miles<65 2012','miles<65 2014','miles<65 2016','target=miles<65 2018']
features = ['Estado','2008','2010','2012','2014','2016','2018','Miles 2008','Miles 2010','Miles 2012','<65 2012','<65 2014','<65 2016','<65 2018','Miles <65 2008','miles<65 2010','miles<65 2012','miles<65 2014','miles<65 2016']
target = ['target=miles<65 2018']

df = pd.read_csv(path, names=all_variables)
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Estado  \
# ...

# %%
df = pd.read_csv(path, names=all_variables)
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Estado  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_sc = pd.DataFrame(columns=features)
df_sc.head()
# Out:
# Empty DataFrame
# Columns: [Estado, 2008, 2010, 2012, 2014, 2016, 2018, Miles 2008, Miles 2010, Miles 2012, <65 2012, <65 2014, <65 2016, <65 2018, Miles <65 2008, miles<65 2010, miles<65 2012, miles<65 2014, miles<65 2016]
# Index: []

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_sc = pd.DataFrame(scaler.fit_transform(df[features]),
                 columns=features)
df_sc.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-e544e6473fd8> in <module>
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 scaler = MinMaxScaler()
# ----> 3 df_sc = pd.DataFrame(scaler.fit_transform(df[features]),
#       4                  columns=features)
#       5 df_sc.head()
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     551         if y is None:
#     552             # fit method of arity 1 (unsupervised transformation)
# --> 553             return self.fit(X, **fit_params).transform(X)
#     554         else:
#     555             # fit method of arity 2 (supervised transformation)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     323         # Reset internal state before fitting
#     324         self._reset()
# ...

# %% [markdown]
# No se puede transformar ninguno de los datos, ya que no puede convertilos.
